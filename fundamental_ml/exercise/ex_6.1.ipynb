# %%
# exercise 6.1 and add Elbow
# source: https://medium.com/@zalarushirajsinh07/the-elbow-method-finding-the-optimal-number-of-clusters-d297f5aeb189

# %%
import numpy as np
import pandas as pd

x = pd.read_csv('../data/data_6_1.csv').to_numpy()
print(x.shape)
# Out:
# (200, 2)

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=5)
model.fit(x)
# Out:
# KMeans(n_clusters=5)

# %%
print('centroids\n', model.cluster_centers_)
print('labels\n', model.labels_)
# Out:
# centroids
#  [[-2.60925     4.949     ]
#  [10.00918919  8.47675676]
#  [-2.32375    11.00025   ]
#  [ 5.18325    -5.3345    ]
#  [ 7.99209302 10.86302326]]
# labels
#  [1 0 4 2 2 4 3 2 1 3 0 2 3 0 4 1 2 1 3 3 0 4 2 2 2 1 4 0 0 3 4 2 3 4 2 0 3
#  1 1 0 3 1 1 0 4 4 2 1 3 3 2 2 4 4 4 3 4 0 0 0 3 3 4 3 0 4 1 0 2 0 2 2 1 0
#  0 2 3 1 2 2 4 2 4 4 1 1 3 3 0 3 0 2 3 1 2 1 3 2 2 1 4 4 3 4 3 1 3 0 0 3 0
#  1 4 4 3 2 4 4 4 1 1 4 2 2 0 0 0 2 2 3 3 0 3 4 2 4 4 2 4 0 1 4 3 3 2 2 4 1
#  0 4 4 0 4 1 3 0 2 4 4 0 4 1 0 2 4 3 1 0 0 2 3 1 1 1 4 1 0 3 2 4 2 3 3 1 2
#  0 1 3 0 0 1 3 0 4 2 1 0 1 1 3]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))
plt.scatter(x=x[:, 0], y=x[:, 1], c="black", s=10)

step = 0.01
xx = np.arange(x[:, 0].min(), x[:, 0].max(), step)
yy = np.arange(x[:, 1].min(), x[:, 1].max(), step)
xx, yy = np.meshgrid(xx, yy)
xy = np.concatenate((xx.reshape(-1, 1), yy.reshape(-1, 1)), axis=1)

z = model.predict(xy)

plt.contourf(xx, yy, z.reshape(xx.shape), cmap=plt.cm.jet, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
# WCSS=[]

from sklearn.cluster import KMeans
WCSS=[]
for i in range(1,20):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(x)
  WCSS.append(kmeans.inertia_)
WCSS

plt.plot(range(1,20),WCSS)
